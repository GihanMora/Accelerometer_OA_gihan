# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from os import listdir, makedirs
from os.path import join, isfile, isdir, exists
from datetime import datetime
import pandas as pd
import numpy as np
import math
from tqdm import tqdm

# %%
# sleep time input_data
sleep_time_file = '/content/drive/My Drive/OA_Gihan/OA_all/OA activity data_La Trobe/Analytics_Scripts/Rashmika_Analysis/metadata/Copy of record_availability_final.csv'
sleep_df = pd.read_csv(sleep_time_file)

# %% [markdown]
# actigraph

# %%
Actigraph_output_folder = '/content/drive/MyDrive/OA activity data_La Trobe/Analytics_Scripts/Gihan_analysis/processed data/montoye_thigh/Epoch30/'

epoch_files = [f for f in listdir(Actigraph_output_folder) if isfile(join(Actigraph_output_folder, f))]
user_ids_graph = []
for each_f in epoch_files:
  user_i = each_f.split('_')[0]
  if(user_i not in user_ids_graph):
    user_ids_graph.append(user_i)

print(user_ids_graph)
print(len(user_ids_graph))
# Out:
# ['KOA47', 'KOA49', 'KOA50', 'KOA53', 'KOA54', 'KOA55', 'KOA56', 'KOA57', 'KOA58', 'KOA59', 'KOA6', 'KOA60', 'KOA61', 'KOA63', 'KOA64', 'KOA66', 'KOA67', 'KOA68', 'KOA69', 'KOA7', 'KOA70', 'KOA71', 'KOA73', 'KOA74', 'KOA75', 'KOA8', 'KOA9', 'OA1', 'OA10', 'OA12', 'OA14', 'OA17', 'OA2', 'OA21', 'OA22', 'OA23', 'OA24', 'OA25', 'OA29', 'OA31', 'OA32', 'OA33', 'OA35', 'OA36', 'OA37', 'OA38', 'OA39', 'OA40', 'OA43', 'OA44', 'OA46', 'OA47', 'OA48', 'OA49', 'OA50', 'OA51', 'OA54', 'OA55', 'OA56', 'OA58', 'OA59', 'OA60', 'OA61', 'OA62', 'OA63', 'OA65', 'OA66', 'OA67', 'OA70', 'OA71', 'OA72', 'OA74', 'OA75', 'OA76', 'OA77', 'OA78', 'OA80', 'OA82', 'OA84', 'OA86', 'OA88', 'OA89', 'OA3', 'OA4', 'OA5', 'OA6', 'OA7', 'OA8', 'OA9', 'HOA10', 'HOA14', 'HOA15', 'HOA16', 'HOA17', 'HOA19', 'HOA2', 'HOA20', 'HOA24', 'HOA26', 'HOA29', 'HOA30', 'HOA32', 'HOA33', 'HOA34', 'HOA35', 'HOA36', 'HOA37', 'HOA39', 'HOA4', 'HOA40', 'HOA41', 'HOA42', 'HOA44', 'HOA46', 'HOA47', 'HOA6', 'HOA7', 'HOA9', 'KOA1', 'KOA12'
# ...

# %%
user_data_graph = {}

for _, row in tqdm(sleep_df.iterrows(), total=sleep_df.shape[0]):
 
  user_id = row['Participant']
  age = row['age_yr']
  bmi = row['BMI']
  # print([user_id,age,bmi])
  if(user_id in user_ids_graph):
    user_data_graph[user_id]=[age,bmi]

print(user_data_graph)
# Out:
# 100%|██████████| 1351/1351 [00:00<00:00, 9143.33it/s]
# ...

# %%
import pandas as pd
graph_df = pd.DataFrame()

age_list = []
bmi_list = []

for k in user_data_graph.keys():
  age_list.append(user_data_graph[k][0])
  bmi_list.append(user_data_graph[k][1])
print(age_list)
print(len(age_list))
print(bmi_list)
print(len(bmi_list))
graph_df['age'] = age_list
graph_df['bmi'] = bmi_list
print('mean')
print(graph_df.mean(axis = 0)) 
print('std')
print(graph_df.std(axis = 0)) 
# print('age_mean',graph_df['age'].mean)
# print('age_std',graph_df['age'].std)
# print('bmi_mean',graph_df['bmi'].mean)
# print('bmi_mean',graph_df['bmi'].std)
# Out:
# [52.0, 51.0, 55.0, 61.0, 76.0, 73.0, 47.0, 69.0, 66.0, 58.0, 69.0, 61.0, 65.0, 46.0, 57.0, 68.0, 49.0, 74.0, 70.0, 79.0, 42.0, 64.0, 69.0, 84.0, 62.0, 63.0, 51.0, 56.0, 62.0, 70.0, 73.0, 48.0, 60.0, 50.0, 64.0, 78.0, 58.0, nan, 75.0, 41.0, 72.0, 60.0, 69.0, 74.0, 50.0, 68.0, 79.0, 69.0, 79.0, 74.0, nan, 79.0, 67.0, 54.0, 66.0, 66.0, 68.0, 69.0, 73.0, 59.0, 82.0, 60.0, 52.0, 71.0, 68.0, 65.0, 56.0, 49.0, 61.0, 56.0, 70.0, 60.0, 79.0, 73.0, 71.0, 58.0, 64.0, 64.0, 67.0, 67.0, 68.0, 55.0, 55.0, 60.0, 70.0, 72.0, 73.0, 61.0, 50.0, 47.0, 86.0, 78.0, 67.0, 72.0, 71.0, 65.0, 75.0, 55.0, 65.0, 50.0, 56.0, 58.0, 63.0, 59.0, 65.0, 78.0, 63.0, 73.0, 80.0, 75.0, 64.0, 70.0, 51.0, 67.0, 65.0, 56.0, 51.0, 66.0, 74.0, 75.0, 61.0, 63.0, 78.0, 77.0, 72.0, 66.0, 58.0, 76.0, 61.0, 63.0, 64.0, 67.0, 73.0, 61.0, 62.0, 63.0, 49.0, 70.0, 62.0, 68.0, 71.0, 71.0]
# 142
# ...
